# %% [markdown]
# ## GEM 2x

# %%
import os
from os.path import join, basename
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set(color_codes=True, style="white")

# %%
folder = r"Z:\Bisal_Halder_turbo\PROCESSED_DATA\Impact_of_cytoskeleton_on_HOPS_condensates\GEM tracking\GGanalyzed-20240808-40nmGEM-20ms-1x2x-triplicate\Analysed data\2x\reformatted"
os.chdir(folder)
fname = "SPT_results_AIO_concat-40nmGEM-48h-2x-20ms.csv"
df_AIO = pd.read_csv(fname)

# Displacement threshold for immobile molecules
immobile_stepsize_threshold_nm = 30
# alpha component threshold for constrained diffusion
# threshold_alpha = 0.7

# %% [markdown]
# ## alpha distribution per track

# %%
plt.figure(figsize=(4, 3))
data = df_AIO[df_AIO["mean_stepsize_nm"] > immobile_stepsize_threshold_nm]
data = data[data["loglog_fit_R2"] > 0.6]
data = data[data["alpha"] > 0]
ax = sns.histplot(
    data=data,
    x="alpha",
    bins=30,
    stat="probability",
    common_norm=False,
    binrange=(0, 2),
    lw=2,
    element="step",
    legend=False,
)
plt.axvline(1, ls="--", c="gray", lw=2)
plt.text(
    0.09,
    0.095,
    r"N$_{traj.}$=" + f"{data.shape[0]:,}",
    fontdict={"fontsize": 18},
)
plt.xlim(0, 2)
plt.ylim(0, 0.11)
plt.xlabel(r"$\alpha$ Component", fontsize=18)
plt.ylabel("Probability", fontsize=18)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(
    axis="both",
    which="major",
    labelsize=18,
    direction="in",
    bottom=True,
    left=True,
    length=5,
    width=1,
)
plt.gca().set_axisbelow(False)
plt.gca().tick_params(axis="both", which="major", labelsize=18)
plt.savefig("alpha_histo.png", format="png", bbox_inches="tight", dpi=300)

# %% [markdown]
# ## Angle distribution

# %%
lst_angle = []
# lst_label = []
for _, row in df_AIO[df_AIO["mean_stepsize_nm"] > immobile_stepsize_threshold_nm].iterrows():
    angles = np.fromstring(
        row["list_of_angles"][1:-1],
        dtype=float,
        sep=", ",
    )
    # labels = np.repeat(row["label"], angles.shape[0])
    lst_angle.extend(angles)
    # lst_label.extend(labels)

data = pd.DataFrame(
    {
        "angle": np.abs(lst_angle),
        # "label": lst_label,
    },
    dtype=object,
)


plt.figure(figsize=(4, 3))
bins = 30
sns.histplot(
    data=data,
    x="angle",
    bins=bins,
    stat="probability",
    common_norm=False,
    binrange=(0, 180),
    lw=2,
    element="step",
    legend=False,
)
plt.axhline(1 / 30, ls="--", c="gray", lw=2)
plt.text(
    10,
    0.05,
    r"N$_{step}$=" + f"{data.shape[0]:,}",
    fontdict={"fontsize":18},
)
plt.xlim(0, 180)
plt.xticks([0, 90, 180])
plt.ylim(0, 0.06)
plt.yticks([0, 0.02, 0.04, 0.06])
plt.xlabel("Angle, $^\circ$", fontsize=18)
plt.ylabel("Probability", fontsize=18)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(
    axis="both",
    which="major",
    labelsize=18,
    direction="in",
    bottom=True,
    left=True,
    length=5,
    width=1,
)
plt.gca().set_axisbelow(False)
plt.gca().tick_params(axis="both", which="major", labelsize=18)
plt.savefig("angle_histo.png", format="png", bbox_inches="tight", dpi=300)

# %% [markdown]
# ## GEM 1x

# %%
import os
from os.path import join, basename
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set(color_codes=True, style="white")

# %%
folder = r"Z:\Bisal_Halder_turbo\PROCESSED_DATA\Impact_of_cytoskeleton_on_HOPS_condensates\GEM tracking\GGanalyzed-20240808-40nmGEM-20ms-1x2x-triplicate\Analysed data\1x\reformatted"
os.chdir(folder)
fname = "SPT_results_AIO_concat-40nmGEM-48h-1x-20ms.csv"
df_AIO = pd.read_csv(fname)

# Displacement threshold for immobile molecules
immobile_stepsize_threshold_nm = 30
# alpha component threshold for constrained diffusion
# threshold_alpha = 0.7

# %% [markdown]
# ## alpha distribution per track

# %%
plt.figure(figsize=(4, 3))
data = df_AIO[df_AIO["mean_stepsize_nm"] > immobile_stepsize_threshold_nm]
data = data[data["loglog_fit_R2"] > 0.6]
data = data[data["alpha"] > 0]
ax = sns.histplot(
    data=data,
    x="alpha",
    bins=30,
    stat="probability",
    common_norm=False,
    binrange=(0, 2),
    lw=2,
    element="step",
    legend=False,
)
plt.axvline(1, ls="--", c="gray", lw=2)
plt.text(
    0.09,
    0.095,
    r"N$_{traj.}$=" + f"{data.shape[0]:,}",
    fontdict={"fontsize": 18},
)
plt.xlim(0, 2)
plt.ylim(0, 0.11)
plt.xlabel(r"$\alpha$ Component", fontsize=18)
plt.ylabel("Probability", fontsize=18)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(
    axis="both",
    which="major",
    labelsize=18,
    direction="in",
    bottom=True,
    left=True,
    length=5,
    width=1,
)
plt.gca().set_axisbelow(False)
plt.gca().tick_params(axis="both", which="major", labelsize=18)
plt.savefig("alpha_histo.png", format="png", bbox_inches="tight", dpi=300)

# %% [markdown]
# ## Angle distribution

# %%
lst_angle = []
# lst_label = []
for _, row in df_AIO[df_AIO["mean_stepsize_nm"] > immobile_stepsize_threshold_nm].iterrows():
    angles = np.fromstring(
        row["list_of_angles"][1:-1],
        dtype=float,
        sep=", ",
    )
    # labels = np.repeat(row["label"], angles.shape[0])
    lst_angle.extend(angles)
    # lst_label.extend(labels)

data = pd.DataFrame(
    {
        "angle": np.abs(lst_angle),
        # "label": lst_label,
    },
    dtype=object,
)


plt.figure(figsize=(4, 3))
bins = 30
sns.histplot(
    data=data,
    x="angle",
    bins=bins,
    stat="probability",
    common_norm=False,
    binrange=(0, 180),
    lw=2,
    element="step",
    legend=False,
)
plt.axhline(1 / 30, ls="--", c="gray", lw=2)
plt.text(
    10,
    0.05,
    r"N$_{step}$=" + f"{data.shape[0]:,}",
    fontdict={"fontsize":18},
)
plt.xlim(0, 180)
plt.xticks([0, 90, 180])
plt.ylim(0, 0.06)
plt.yticks([0, 0.02, 0.04, 0.06])
plt.xlabel("Angle, $^\circ$", fontsize=18)
plt.ylabel("Probability", fontsize=18)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(
    axis="both",
    which="major",
    labelsize=18,
    direction="in",
    bottom=True,
    left=True,
    length=5,
    width=1,
)
plt.gca().set_axisbelow(False)
plt.gca().tick_params(axis="both", which="major", labelsize=18)
plt.savefig("angle_histo.png", format="png", bbox_inches="tight", dpi=300)

# %% [markdown]
# ## GEM and HOPS comparison : alpha component probability distribution

# %%
import os
from os.path import join, basename
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tkinter import filedialog

sns.set(color_codes=True, style="white")

# %%
# Use file dialog to select CSV files for each condition
csv_files_1 = filedialog.askopenfilenames(
    title="Select CSV Files for HOPS",
    filetypes=(("CSV files", "*.csv"), ("All files", "*.*")),
)
csv_files_2 = filedialog.askopenfilenames(
    title="Select CSV Files for GEM",
    filetypes=(("CSV files", "*.csv"), ("All files", "*.*")),
)

# %%
def load_and_label(csv_files, label):
    dfs = []
    for file in csv_files:
        df = pd.read_csv(file)
        df['label'] = label
        dfs.append(df)
    return pd.concat(dfs, ignore_index=True)

# %%
immobile_stepsize_threshold_nm = 30
def filter_data(df):
    return df[(df["mean_stepsize_nm"] > immobile_stepsize_threshold_nm) & 
              (df["loglog_fit_R2"] > 0.6) & 
              (df["alpha"] > 0)]

# %%
df_hops = load_and_label (csv_files_1, "HOPS")
df_gem = load_and_label (csv_files_2, "GEM")

# %%
df_hops = filter_data(df_hops)
df_gem = filter_data(df_gem)

# %%
combined_data = pd.concat([df_hops, df_gem], ignore_index=True)

# %%
# Plot the probability distribution for each condition without KDE
plt.figure(figsize=(6,4))
ax = sns.histplot(
    data=combined_data,
    x='alpha',
    hue='label',
    bins=30,
    binrange = (0,2),
    stat="probability",
    element="step",
    common_norm=False,
    fill=True,
    alpha=0.2  
)
plt.axvline(1, ls="--", c="gray", lw=2)

legend = ax.get_legend()
legend.set_title(None)
legend_frame = legend.get_frame()
legend_frame.set_visible(False)

plt.xlim(0, 2)
plt.ylim(0, 0.085)
plt.xlabel(r"$\alpha$ Component", fontsize=18)
plt.ylabel("Probability", fontsize=18)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(
    axis="both",
    which="major",
    labelsize=18,
    direction="in",
    bottom=True,
    left=True,
    length=5,
    width=1,
)
plt.gca().set_axisbelow(False)
plt.gca().tick_params(axis="both", which="major", labelsize=18)
plt.savefig("alpha_histo.png", format="png", bbox_inches="tight", dpi=300)

# %% [markdown]
# ## GEM and HOPS comparison : alpha component CDF

# %%
# Plot the CDF
plt.figure(figsize=(6, 4))
ax = sns.histplot(
    data=combined_data,
    x='alpha',
    hue='label',  
    bins=30,
    binrange=(0, 2),
    stat="probability",
    element="step",
    common_norm=False,
    cumulative=True,  
    fill=False,
    lw = 3   
)

legend = ax.get_legend()
legend.set_title(None)
legend_frame = legend.get_frame()
legend_frame.set_visible(True)

plt.xlim(0, 2)
plt.xlabel(r"$\alpha$ Component", fontsize=18)
plt.ylabel("Cumulative Probability", fontsize=18)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(
    axis="both",
    which="major",
    labelsize=18,
    direction="in",
    bottom=True,
    left=True,
    length=5,
    width=1,
)
plt.gca().set_axisbelow(False)
plt.gca().tick_params(axis="both", which="major", labelsize=18)
plt.savefig("alpha_cdf.png", format="png", bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# ## GEM and HOPS comparison : angle distribution

# %%
import os
from os.path import join, basename
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tkinter import filedialog

sns.set(color_codes=True, style="white")

# %%
# Use file dialog to select CSV files for each condition
csv_files_1 = filedialog.askopenfilenames(
    title="Select CSV Files for HOPS",
    filetypes=(("CSV files", "*.csv"), ("All files", "*.*")),
)
csv_files_2 = filedialog.askopenfilenames(
    title="Select CSV Files for GEM",
    filetypes=(("CSV files", "*.csv"), ("All files", "*.*")),
)

# %%
# Function to load CSV files and add a 'Condition' column
def load_and_label_files(file_paths, label):
    dfs = [pd.read_csv(file) for file in file_paths]
    for df in dfs:
        df['label'] = label
    combined_df = pd.concat(dfs)
    return combined_df

# %%
# Load and label CSV files for each condition
df_condition1 = load_and_label_files(csv_files_1, 'HOPS')
df_condition2 = load_and_label_files(csv_files_2, 'GEM')

# %%
# Combine the data from all conditions
df_combined = pd.concat([df_condition1, df_condition2], ignore_index=True)

# %%
immobile_stepsize_threshold_nm = 30

lst_angle = []
lst_condition = []

for _, row in df_combined[df_combined["mean_stepsize_nm"] > immobile_stepsize_threshold_nm].iterrows():
    angles = np.fromstring(
        row["list_of_angles"][1:-1],
        dtype=float,
        sep=", ",
    )
    lst_angle.extend(angles)
    lst_condition.extend([row["label"]] * len(angles))

data = pd.DataFrame(
    {
        "angle": np.abs(lst_angle),
        "label": lst_condition,
    },
    dtype=object,
)

# %%
plt.figure(figsize=(6, 4))
bins = 30
ax = sns.histplot(
    data=data,
    x="angle",
    hue="label",
    bins=bins,
    stat="probability",
    common_norm=False,
    binrange=(0, 180),
    lw=2,
    element="step",
    fill=True,
    alpha=0.4,
)

# Customize and annotate the plot
plt.axhline(1 / bins, ls="--", c="gray", lw=2)
plt.xlim(0, 180)
plt.xticks([0, 90, 180])
plt.ylim(0, 0.06)
plt.yticks([0, 0.02, 0.04, 0.06])
plt.xlabel("Angle, $^\circ$", fontsize=18)
plt.ylabel("Probability", fontsize=18)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(
    axis="both",
    which="major",
    labelsize=18,
    direction="in",
    bottom=True,
    left=True,
    length=5,
    width=1,
)
plt.gca().set_axisbelow(False)
plt.gca().tick_params(axis="both", which="major", labelsize=18)

# Customize the legend
legend = ax.get_legend()
if legend is not None:
    legend.set_title(None)
    legend_frame = legend.get_frame()
    legend_frame.set_visible(False)


# Final layout adjustments and saving
plt.tight_layout()
plt.savefig("angle_histo.png", format="png", bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# ## GEM Tracking : Comparison between 1x and 2x, alpha component probability distribuion

# %%
import os
from os.path import join, basename
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tkinter import filedialog

sns.set(color_codes=True, style="white")

# %%
# Use file dialog to select CSV files for each condition
csv_files_1 = filedialog.askopenfilenames(
    title="Select CSV Files for 1x",
    filetypes=(("CSV files", "*.csv"), ("All files", "*.*")),
)
csv_files_2 = filedialog.askopenfilenames(
    title="Select CSV Files for 2x",
    filetypes=(("CSV files", "*.csv"), ("All files", "*.*")),
)

# %%
def load_and_label(csv_files, label):
    dfs = []
    for file in csv_files:
        df = pd.read_csv(file)
        df['label'] = label
        dfs.append(df)
    return pd.concat(dfs, ignore_index=True)

# %%
immobile_stepsize_threshold_nm = 30
def filter_data(df):
    return df[(df["mean_stepsize_nm"] > immobile_stepsize_threshold_nm) & 
              (df["loglog_fit_R2"] > 0.6) & 
              (df["alpha"] > 0)]

# %%
df_1x = load_and_label (csv_files_1, "GEM, 1x")
df_2x = load_and_label (csv_files_2, "GEM, 2x")

# %%
df_1x = filter_data(df_1x)
df_2x = filter_data(df_2x)

# %%
combined_data = pd.concat([df_1x, df_2x], ignore_index=True)

# %%
# Plot the probability distribution for each condition without KDE
plt.figure(figsize=(6,4))
ax = sns.histplot(
    data=combined_data,
    x='alpha',
    hue='label',
    bins=30,
    binrange = (0,2),
    stat="probability",
    element="step",
    common_norm=False,
    fill=True,
    alpha=0.2  
)
plt.axvline(1, ls="--", c="gray", lw=2)

legend = ax.get_legend()
legend.set_title(None)
legend_frame = legend.get_frame()
legend_frame.set_visible(False)

plt.xlim(0, 2)
plt.ylim(0, 0.085)
plt.xlabel(r"$\alpha$ Component", fontsize=18)
plt.ylabel("Probability", fontsize=18)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(
    axis="both",
    which="major",
    labelsize=18,
    direction="in",
    bottom=True,
    left=True,
    length=5,
    width=1,
)
plt.gca().set_axisbelow(False)
plt.gca().tick_params(axis="both", which="major", labelsize=18)
plt.savefig("alpha_histo.png", format="png", bbox_inches="tight", dpi=300)

# %% [markdown]
# ## GEM Tracking : Comparison between 1x and 2x, angle distribuion

# %%
import os
from os.path import join, basename
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tkinter import filedialog

sns.set(color_codes=True, style="white")

# %%
# Use file dialog to select CSV files for each condition
csv_files_1 = filedialog.askopenfilenames(
    title="Select CSV Files for 1x",
    filetypes=(("CSV files", "*.csv"), ("All files", "*.*")),
)
csv_files_2 = filedialog.askopenfilenames(
    title="Select CSV Files for 2x",
    filetypes=(("CSV files", "*.csv"), ("All files", "*.*")),
)

# %%
def load_and_label(csv_files, label):
    dfs = []
    for file in csv_files:
        df = pd.read_csv(file)
        df['label'] = label
        dfs.append(df)
    return pd.concat(dfs, ignore_index=True)

# %%
df_1x = load_and_label (csv_files_1, "GEM, 1x")
df_2x = load_and_label (csv_files_2, "GEM, 2x")

# %%
df_combined = pd.concat([df_1x, df_2x], ignore_index=True)

# %%
immobile_stepsize_threshold_nm = 30

lst_angle = []
lst_condition = []

for _, row in df_combined[df_combined["mean_stepsize_nm"] > immobile_stepsize_threshold_nm].iterrows():
    angles = np.fromstring(
        row["list_of_angles"][1:-1],
        dtype=float,
        sep=", ",
    )
    lst_angle.extend(angles)
    lst_condition.extend([row["label"]] * len(angles))

data = pd.DataFrame(
    {
        "angle": np.abs(lst_angle),
        "label": lst_condition,
    },
    dtype=object,
)

# %%
plt.figure(figsize=(6, 4))
bins = 30
ax = sns.histplot(
    data=data,
    x="angle",
    hue="label",
    bins=bins,
    stat="probability",
    common_norm=False,
    binrange=(0, 180),
    lw=2,
    element="step",
    fill=True,
    alpha=0.4,
)

# Customize and annotate the plot
plt.axhline(1 / bins, ls="--", c="gray", lw=2)
plt.xlim(0, 180)
plt.xticks([0, 90, 180])
plt.ylim(0, 0.06)
plt.yticks([0, 0.02, 0.04, 0.06])
plt.xlabel("Angle, $^\circ$", fontsize=18)
plt.ylabel("Probability", fontsize=18)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(
    axis="both",
    which="major",
    labelsize=18,
    direction="in",
    bottom=True,
    left=True,
    length=5,
    width=1,
)
plt.gca().set_axisbelow(False)
plt.gca().tick_params(axis="both", which="major", labelsize=18)

# Customize the legend
legend = ax.get_legend()
if legend is not None:
    legend.set_title(None)
    legend_frame = legend.get_frame()
    legend_frame.set_visible(False)


# Final layout adjustments and saving
plt.tight_layout()
plt.savefig("angle_histo.png", format="png", bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# ## GEM_Nocodazole treatment

# %%
import os
from os.path import join, basename
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tkinter import filedialog

sns.set(color_codes=True, style="white")

# %%
# Use file dialog to select CSV files for each condition
csv_files_1 = filedialog.askopenfilenames(
    title="Select CSV Files for No drug_2x",
    filetypes=(("CSV files", "*.csv"), ("All files", "*.*")),
)
csv_files_2 = filedialog.askopenfilenames(
    title="Select CSV Files for Nocodazole_30 mins",
    filetypes=(("CSV files", "*.csv"), ("All files", "*.*")),
)
csv_files_3 = filedialog.askopenfilenames(
    title="Select CSV Files for Nocodazole_60 mins",
    filetypes=(("CSV files", "*.csv"), ("All files", "*.*")),
)

# %%
# Function to load CSV files and add a 'Condition' column
def load_and_label_files(file_paths, label):
    dfs = [pd.read_csv(file) for file in file_paths]
    for df in dfs:
        df['Condition'] = label
    combined_df = pd.concat(dfs)
    return combined_df

# %%
# Load and label CSV files for each condition
df_condition1 = load_and_label_files(csv_files_1, '- Noco')
df_condition2 = load_and_label_files(csv_files_2, '+ Noco, 30 mins')
df_condition3 = load_and_label_files(csv_files_3, '+ Noco, 60 mins')

# %%
df_combined = pd.concat([df_condition1, df_condition2, df_condition3], ignore_index=True)

# %%
immobile_stepsize_threshold_nm = 30

lst_angle = []
lst_condition = []

for _, row in df_combined[df_combined["mean_stepsize_nm"] > immobile_stepsize_threshold_nm].iterrows():
    angles = np.fromstring(
        row["list_of_angles"][1:-1],
        dtype=float,
        sep=", ",
    )
    lst_angle.extend(angles)
    lst_condition.extend([row["Condition"]] * len(angles))

data = pd.DataFrame(
    {
        "angle": np.abs(lst_angle),
        "Condition": lst_condition,
    },
    dtype=object,
)

# %%
plt.figure(figsize=(6, 4))
bins = 30
ax = sns.histplot(
    data=data,
    x="angle",
    hue="Condition",
    bins=bins,
    stat="probability",
    common_norm=False,
    binrange=(0, 180),
    lw=2,
    element="step",
    fill=True,
    alpha=0.4,
)

# Customize and annotate the plot
plt.axhline(1 / bins, ls="--", c="gray", lw=2)
plt.xlim(0, 180)
plt.xticks([0, 90, 180])
plt.ylim(0, 0.06)
plt.yticks([0, 0.02, 0.04, 0.06])
plt.xlabel("Angle, $^\circ$", fontsize=18)
plt.ylabel("Probability", fontsize=18)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(
    axis="both",
    which="major",
    labelsize=18,
    direction="in",
    bottom=True,
    left=True,
    length=5,
    width=1,
)
plt.gca().set_axisbelow(False)
plt.gca().tick_params(axis="both", which="major", labelsize=18)

# Customize the legend
legend = ax.get_legend()
if legend is not None:
    legend.set_title(None)
    legend_frame = legend.get_frame()
    legend_frame.set_visible(False)
    # ax.legend(loc='upper left', bbox_to_anchor=(-0.15, 1))


# Final layout adjustments and saving
plt.tight_layout()
plt.savefig("angle_histo.png", format="png", bbox_inches="tight", dpi=300)
plt.show()
