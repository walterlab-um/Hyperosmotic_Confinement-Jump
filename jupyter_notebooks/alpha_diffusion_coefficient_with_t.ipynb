# %% [markdown]
# ## Diffusion coefficient and alpha variation with time by running window analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as clr
import seaborn as sns
import matplotlib.cm as cm
from scipy import stats

# %%
# Load the CSV file
file_path = r'Z:\Bisal_Halder_turbo\PROCESSED_DATA\Impact_of_cytoskeleton_on_HOPS_condensates\no_drug\Analysed Data\2x\Trackmate analysis new 07052024\flagged_tracks_w20\20240118_UGD-2x-2s-replicate1-FOV-2-wstepflags.csv' 
data = pd.read_csv(file_path)

# %%
# Ensure step_flag is boolean and filter for True values
data['step_flag'] = data['step_flag'].astype(str).str.upper() == 'TRUE'

# %%
def has_consecutive_true(df, col='step_flag'):
    return df[col].rolling(window=2).apply(lambda x: all(x), raw=True).any()

valid_track_ids = data.groupby('trackID').filter(has_consecutive_true)['trackID'].unique()
if len(valid_track_ids) == 0:
    raise ValueError("No trackIDs found with consecutive TRUE values in step_flag.")

# %%
track_id = 195

# %%
# track_id = np.random.choice(valid_track_ids, 1)[0]
track_data = data[data['trackID'] == track_id].copy()

# %%
um_per_pixel = 0.117
track_data['x'] = track_data['x'] * um_per_pixel
track_data['y'] = track_data['y'] * um_per_pixel

# %%
s_per_frame = 2
track_data['t'] = track_data['t'] * s_per_frame

# %%
# Store results for future access and extract values
stored_track_data = track_data.copy()
stored_random_track_id = track_id
x = track_data['x'].values
y = track_data['y'].values
t = track_data['t'].values

# Debugging: Print x, y, t values
print("Debug information:")
print("Stored Track Data:")
print(stored_track_data)
# Out:
# Debug information:
# Stored Track Data:
#        trackID          x          y      t  R2  alpha   D  step_sizes  \
# 32151      195  35.795500  57.641286    0.0 NaN    NaN NaN         NaN
# 32152      195  35.810790  57.643472    2.0 NaN    NaN NaN    0.132018
# 32153      195  35.748289  57.626420    4.0 NaN    NaN NaN    0.553720
# 32154      195  35.779825  57.588105    6.0 NaN    NaN NaN    0.424137
# 32155      195  35.765743  57.622542    8.0 NaN    NaN NaN    0.317994
# ...        ...        ...        ...    ...  ..    ...  ..         ...
# 32346      195  35.066147  58.980443  390.0 NaN    NaN NaN    0.235306
# 32347      195  35.043979  59.036088  392.0 NaN    NaN NaN    0.511944
# 32348      195  35.133603  58.987121  394.0 NaN    NaN NaN    0.872894
# 32349      195  35.192316  58.998522  396.0 NaN    NaN NaN    0.511196
# 32350      195  35.118890  58.968847  398.0 NaN    NaN NaN    0.676886
#
#        mean_step_sizes      x_mean      y_mean cellID  step_flag
# 32151         0.382718  302.620756  497.507184  cell2      False
# 32152         0.382718  302.620756  497.507184  cell2      False
# 32153         0.382718  302.620756  497.507184  cell2      False
# 32154         0.382718  302.620756  497.507184  cell2      False
# 32155         0.382718  302.620756  497.507184  cell2      False
# ...                ...         ...         ...    ...        ...
# 32346         0.382718  302.620756  497.507184  cell2      False
# 32347         0.382718  302.620756  497.507184  cell2      False
# 32348         0.382718  302.620756  497.507184  cell2      False
# 32349         0.382718  302.620756  497.507184  cell2      False
# 32350         0.382718  302.620756  497.507184  cell2      False
#
# [200 rows x 13 columns]

# %%
cmap_color_start = "#FFCB05"
cmap_color_end = "#00274C"
cmap_name = "maize2blue"
cmap = clr.LinearSegmentedColormap.from_list(cmap_name, [cmap_color_start, cmap_color_end], N=len(t))
fontsize = 18
x_plot = x - (x.min() + x.max()) / 2
y_plot = y - (y.min() + y.max()) / 2

print(f"x_plot: {x_plot}")
print(f"y_plot: {y_plot}")

fig, ax = plt.subplots(figsize=(6, 4))

# Plot the trajectory with color mapping
for i in range(len(t) - 1):
    ax.plot(
        x_plot[i:i + 2], y_plot[i:i + 2], "-o",
        color=cmap(i / len(t)),
        linewidth=2
    )

# Customize plot aesthetics
ax.axis("scaled")
ax.spines[:].set_linewidth(1)
ax.tick_params(
    axis="both",
    which="major",
    labelsize=fontsize,
    direction="in",
    bottom=True,
    left=True,
    length=5,
    width=1
)
ax.set_xlabel('X, um', fontsize=18)
ax.set_ylabel('Y, um', fontsize=18)

ax.relim()
ax.autoscale_view()

normalize = clr.Normalize(vmin=t.min(), vmax=t.max())
cbar = plt.colorbar(
    cm.ScalarMappable(norm=normalize, cmap=cmap),
    ax=ax,
    orientation='horizontal',
    pad=0.2,
    drawedges=False
)
cbar.ax.tick_params(labelsize=fontsize)
cbar.set_label('Time (s)', fontsize=18)
# Final layout adjustments and show the plot
plt.tight_layout()
plt.show()
# Out:
# x_plot: [ 0.4616084   0.47689894  0.41439821  0.44593362  0.43185214  0.41558164
#   0.3590464   0.3236465   0.32054197  0.32933356  0.29986493  0.32467625
#   0.27481642  0.30631151  0.28951638  0.29152977  0.31480902  0.30925238
#   0.28265673  0.30382969  0.34489401  0.32580336  0.30919077  0.34670388
#   0.33898852  0.31522696  0.34362661  0.32106883  0.29099388  0.30014734
#   0.30095705  0.30530015  0.29224565  0.26886478  0.26001974  0.17839287
#   0.20002998  0.17181511  0.13045355  0.13944681  0.15463701  0.17591318
#   0.19732491  0.11746769  0.15062427  0.14333176  0.17624218  0.18589371
#   0.24727969  0.21632976  0.2456313   0.26075516  0.27335231  0.29798514
#   0.31079587  0.27780463  0.27367373  0.25297684  0.25992257  0.23036423
#   0.23419359  0.23787011  0.24517433  0.26882592  0.2403292   0.2349906
#   0.27532406  0.29641649  0.25658491  0.24605144  0.27226769  0.2979295
#   0.30893119  0.26639484  0.2831583   0.26803616  0.2865633   0.26921287
#   0.29443662  0.29633761  0.29113795  0.29032722  0.2940307   0.294785
#   0.29245954  0.29197231  0.31148435  0.27767052  0.28861277  0.30184842
#   0.29401352  0.33516534  0.31411758  0.28581707  0.26545868  0.24706234
#   0.30363327  0.2197179   0.23784847  0.2500149   0.23969921  0.23063294
#   0.27696008  0.26958921  0.24106608  0.22641423  0.19912806  0.22515762
#   0.25161838  0.24903251  0.28501929  0.29152893  0.27250511  0.2848476
#   0.29252642  0.27670943  0.24286816 -0.04047592 -0.26793646 -0.45035193
#  -0.47689894 -0.44609012 -0.36856647 -0.32738115 -0.3251193  -0.35787604
#  -0.26560473 -0.29401615 -0.31541098 -0.32565882 -0.3450456  -0.35021188
#  -0.37921555 -0.3638883  -0.34929509 -0.34811543 -0.36340142 -0.3199728
#  -0.28613177 -0.27287504 -0.23356137 -0.22895207 -0.19861782 -0.21539822
#  -0.20365294 -0.19076011 -0.18748551 -0.1911879  -0.22611374 -0.27363467
#  -0.26836076 -0.26781241 -0.3172021  -0.32709147 -0.3348961  -0.31323184
#  -0.24678086 -0.24591152 -0.24988262 -0.22401345 -0.24537296 -0.2176698
#  -0.24417207 -0.28016814 -0.2391746  -0.17094793 -0.13562357 -0.16111681
#  -0.13833001 -0.11304599 -0.12443622 -0.12198756 -0.13204209 -0.06074836
#  -0.06412384 -0.05836209 -0.05113515  0.0162772  -0.05016513 -0.00834991
#  -0.02538455 -0.09222777 -0.07670318 -0.0987408  -0.1157641  -0.09902549
#  -0.06761902 -0.07633303 -0.09567975 -0.06920128 -0.06717895 -0.05923578
#  -0.14687489 -0.15144269 -0.24193581 -0.26774395 -0.28991228 -0.20028817
#  -0.14157504 -0.21500104]
# y_plot: [-0.66214958 -0.65996287 -0.67701523 -0.7153305  -0.68089295 -0.61825442
#  -0.63619721 -0.6812471  -0.69290083 -0.68568228 -0.68234571 -0.73265242
#  -0.71251559 -0.70053212 -0.68053868 -0.69134428 -0.69246857 -0.66902803
#  -0.65967264 -0.63472346 -0.62086653 -0.61830325 -0.54372924 -0.57685072
#  -0.56644168 -0.54405481 -0.53707309 -0.56982179 -0.62518052 -0.63612558
#  -0.62807169 -0.5453435  -0.57836125 -0.58037702 -0.56716805 -0.57126704
#  -0.57329015 -0.59170185 -0.51844427 -0.50444031 -0.50813319 -0.52140345
#  -0.51322892 -0.50982798 -0.53544154 -0.57973041 -0.56163243 -0.59020464
#  -0.60232072 -0.62441281 -0.63047976 -0.58447909 -0.59267983 -0.60461777
#  -0.61804734 -0.58801528 -0.59118445 -0.57588245 -0.5827049  -0.55699809
#  -0.52868492 -0.58830007 -0.59062969 -0.5656457  -0.60433177 -0.60824371
#  -0.62415671 -0.60199017 -0.607091   -0.58857474 -0.59972532 -0.58845513
#  -0.59391112 -0.5727892  -0.56908143 -0.51125321 -0.53046495 -0.56999936
#  -0.5359814  -0.53209035 -0.57206678 -0.61537226 -0.62691442 -0.61894186
#  -0.52947319 -0.53651018 -0.54398775 -0.57424103 -0.56508949 -0.56111781
#  -0.57970798 -0.59696569 -0.61630537 -0.6094596  -0.61722501 -0.61849007
#  -0.55298318 -0.54427357 -0.60591421 -0.65290898 -0.65758096 -0.61863917
#  -0.62114235 -0.61899764 -0.60834712 -0.57765271 -0.6021133  -0.58542165
#  -0.53469795 -0.53862567 -0.48839544 -0.46412597 -0.43390791 -0.42472702
#  -0.39727008 -0.32935561 -0.34541895 -0.09084167  0.51963024  0.67458761
#   0.69149153  0.70100439  0.70060557  0.64247162  0.64930535  0.59769659
#   0.50874994  0.4978654   0.52558641  0.49513781  0.49467039  0.58653616
#   0.59305298  0.56431775  0.53571759  0.54473134  0.61296009  0.643246
#   0.67450599  0.67192686  0.67461902  0.67927943  0.72181124  0.72176491
#   0.66334415  0.68892657  0.68727052  0.66626147  0.65684681  0.64592269
#   0.63065511  0.66750585  0.65405032  0.63513656  0.63752712  0.59247356
#   0.65075326  0.57722336  0.51396816  0.44434746  0.45698277  0.47324067
#   0.47646065  0.44108748  0.50281713  0.54249466  0.61469369  0.60576914
#   0.65513607  0.67546324  0.6717769   0.5827257   0.60835401  0.56708833
#   0.49502382  0.49128441  0.49143811  0.50111645  0.55181811  0.56910981
#   0.58104194  0.60451935  0.62955307  0.61724976  0.62706808  0.62753078
#   0.60928812  0.57291006  0.60324852  0.60794917  0.60957669  0.61658107
#   0.68131515  0.66383173  0.6865939   0.67700835  0.73265242  0.68368541
#   0.69508681  0.66541226]

# %%
# Define the MSD calculation function
def calc_MSD_NonPhysUnit(df_track, lags):
    df_track_sorted = df_track.sort_values("t")
    # Prepare storage arrays
    MSDs = []

    # Calculate MSDs corresponding to a series of lag times
    for lag in lags:
        Xs = np.array(df_track_sorted .x, dtype=float)
        Ys = np.array(df_track_sorted .y, dtype=float)

        SquareDisplacements = (Xs[lag:] - Xs[:-lag]) ** 2 + (Ys[lag:] - Ys[:-lag]) ** 2
        MSD = np.nanmean(SquareDisplacements)
        MSDs.append(MSD)

    MSDs = np.array(MSDs, dtype=float)
    return MSDs

# %%
# Running window analysis
window_size = 20
lags = np.linspace(1, window_size, window_size).astype(int)
lst_t_start = []
lst_log10D = []
lst_alpha = []
lst_step_size = []
# Set a minimal for how many datapoints needed to calculate the last MSD value (of the largest lag)
minimal_datapoints = 5

df_track = stored_track_data.copy()  # Use stored data for window analysis

for i in range(df_track.shape[0] - lags.shape[0] - minimal_datapoints):
    MSDs = calc_MSD_NonPhysUnit(
        df_track.iloc[i: i + lags.shape[0] + minimal_datapoints], lags
    )
    if np.isnan(MSDs).any():
        print(i)
    lags_phys = lags 
    MSDs_phys = MSDs 
    # slope_linear, intercept_linear, R_linear, P, std_err = stats.linregress(
    #     lags_phys, MSDs_phys
    # )
    # D_phys_linear = slope_linear / (8 / 3)  # um^2/s
    slope_loglog, intercept_loglog, R_loglog, P, std_err = stats.linregress(
        np.log10(lags_phys),
        np.log10(MSDs_phys),
    )
    D_loglog = (10**intercept_loglog) / (4)
    alpha = slope_loglog

    lst_t_start.append(df_track.iloc[i:i + lags.shape[0]]["t"].mean())
    lst_log10D.append(D_loglog)
    lst_alpha.append(alpha)

    # Calculate mean step sizes for each segment
    segment = df_track.iloc[i:i+lags.shape[0]]
    x_diffs = np.diff(segment['x'])
    y_diffs = np.diff(segment['y'])
    step_sizes = np.sqrt(x_diffs**2 + y_diffs**2)
    mean_step_size = np.mean(step_sizes)
    lst_step_size.append(mean_step_size)

arr_t_start = np.array(lst_t_start, dtype=float)
arr_t_start = arr_t_start - arr_t_start[0]
arr_log10D = np.array(lst_log10D, dtype=float)
arr_alpha = np.array(lst_alpha, dtype=float)
arr_step_size = np.array(lst_step_size, dtype=float)

# %%
# Print lists of alpha, diffusion coefficient, and step sizes
print("List of alpha values:")
print(lst_alpha)
print("\nList of diffusion coefficients (D_loglog):")
print(lst_log10D)
print("\nList of step sizes:")
print(lst_step_size)
# Out:
# List of alpha values:
# [0.8721798398821169, 0.8514463185279029, 0.8588207395125306, 0.8704422446790676, 0.7873157610139578, 0.7358443558273817, 0.759826247526127, 0.8351341470209825, 0.8171938808788781, 0.7909609409565171, 0.7970244251027543, 0.8020339888631842, 0.7825229940260771, 0.7862091654019333, 0.8282283829657915, 0.8928922577743554, 0.9421458989582271, 0.9650383820123617, 0.978035257930301, 1.0369617761314194, 1.0609068710219602, 1.0402884232532885, 1.0312041440631694, 1.0136636054141117, 0.8951708069745581, 0.8043334625849363, 0.7270576198519834, 0.5966640138465676, 0.4665412194584352, 0.4184850888755519, 0.4545072386836519, 0.5199072144183109, 0.5655332652080712, 0.6347594385895261, 0.7442488540297496, 0.8070609087895115, 0.7776121593168436, 0.8011834634953346, 0.8569413060037997, 0.798927336881502, 0.7057670115657249, 0.6282394842862459, 0.5839728553973134, 0.5858236497783457, 0.4267660939436171, 0.3236032618740986, 0.17898924983145095, 0.07556768748159781, -0.04303512238521378, -0.024571356509600833, -0.08796169237086819, 0.03730696429273019, 0.1267059106035795, 0.13196870390596688, 0.21591925860279135, 0.3173240063664614, 0.33993438848783625, 0.30645299678619303, 0.287787139972558, 0.2900669412405913, 0.28374077718764257, 0.3213568558900837, 0.31420525611802497, 0.2633494438587726, 0.2685392099270617, 0.21258485669674457, 0.12651862626389274, 0.06501129563374132, 0.09971770728179205, 0.0875581504582584, 0.124557118172097, 0.23912661376011568, 0.19898593113191806, 0.2329134892646436, 0.26355845089514734, 0.3253476459507281, 0.313000078193722, 0.32464577198533096, 0.3374812429614926, 0.3383758778643904, 0.3363859417919871, 0.33018582865608065, 0.40670230971101745, 0.44702387901483087, 0.4834996710387228, 0.4359511074944402, 0.4377594646992195, 0.48537142284508256, 0.6175369744963602, 0.7314239338903077, 0.8517193850158064, 0.9810222256642194, 1.069759675607031, 0.9135875825289105, 0.849070627802178, 0.9634004817417816, 1.0884969515312182, 1.2004460058927502, 1.2906167338060845, 1.3504572308706437, 1.39204127572447, 1.4145724730150522, 1.4109401247360445, 1.3995830898781363, 1.3844368828345752, 1.3618140734089528, 1.3367959783833914, 1.3111282596195868, 1.282498916988097, 1.2450812381321015, 1.1945933356526013, 1.1325197733691337, 1.055319698730064, 0.9596591882190201, 0.8421543201328033, 0.709808840808479, 0.569677459237778, 0.3991556920306796, 0.4603756214348798, 0.7030882194760162, 0.7169666701801921, 0.760877171584215, 0.8422104498250944, 0.9323234757675968, 0.9802715802974383, 1.026910888109058, 1.0739155731307954, 1.0373404318677817, 0.9499339438141766, 0.8722123194460334, 0.775618202846162, 0.6664213865949951, 0.5582806612232261, 0.484432083897124, 0.5145636552973959, 0.6288066901048686, 0.7723047942431159, 0.8851239326971112, 0.9839614610460371, 1.0613687815854307, 1.0751265052095365, 1.0243267401805554, 0.9330908793248581, 0.8422883840366457, 0.7249836270304755, 0.6942982249621885, 0.665030485558647, 0.6615090068401702, 0.7023756400807852, 0.7664321630518962, 0.7802670131357409, 0.8073153077905901, 0.8359452428700552, 0.8601371863099229, 0.8435774954513803, 0.8551945979276547, 0.8730716220639314, 0.8823723219765861, 0.8862962105442375, 0.8616796555031732, 0.7998007068468799, 0.7154232435124463, 0.6501111316317901, 0.5517380799012043, 0.3607738600991484, 0.19139306334810482, 0.16270976014743, 0.2149976713534067, 0.3317398901510415, 0.45276749361760005, 0.6339506402963597, 0.7984744648121171, 0.9289709363861897, 0.9970510019797781, 0.9922648896135662]
#
# List of diffusion coefficients (D_loglog):
# [0.0004419854930054436, 0.0004535930666570512, 0.00042724561498466517, 0.00041162233503238383, 0.0004371822621794535, 0.00043931830995575535, 0.0003791898859166652, 0.0003465420762042604, 0.0003609962735752002, 0.00038010364781371745, 0.00037869316065741954, 0.0004244136868642497, 0.0004384184145769462, 0.00045300001420231153, 0.0004861166863993858, 0.0004817339456614658, 0.00046221619858136917, 0.0004453803052345104, 0.0004360935805470173, 0.0004105713160671223, 0.00039508486083166385, 0.00041118667397194506, 0.0004084389688369199, 0.00042109412839533083, 0.0005212444343692707, 0.00059954980125576, 0.0006767348320709666, 0.0007847956826115779, 0.0009201293998291667, 0.0009901712861795867, 0.0009307852042401821, 0.0008004202876534082, 0.0007160953026256652, 0.0006173980211584671, 0.0004996812355043881, 0.0004281482231189807, 0.0004533828359468896, 0.00042812028206796007, 0.0003692655929310546, 0.0003912002196863923, 0.0004298721311284793, 0.00045709338819139265, 0.00047221254371814756, 0.0004395049850137628, 0.0004578519113812461, 0.0004621579229147143, 0.0004779044206868844, 0.0004959304935813592, 0.0005414790423483917, 0.0005294998622373008, 0.000538513758505236, 0.0004954210284469418, 0.00046476369782392786, 0.00046823480557828793, 0.00042527800933042935, 0.00035391004988325023, 0.00034649692098545073, 0.0003836239355064934, 0.00042167489112334593, 0.00043173906529412324, 0.0004627793368055856, 0.0004203015186836263, 0.00043177561887545546, 0.0004644848042170499, 0.0004530639871311614, 0.00047682612074766997, 0.0005091102287455457, 0.0005603156771497426, 0.0005414373001478463, 0.0005442187628128961, 0.0005216153214506275, 0.00046526280698799014, 0.0005139060629406756, 0.0005417144667716871, 0.0005456747946142304, 0.0005453921798812286, 0.000575706887183308, 0.000576404462857577, 0.0005740728733286087, 0.0005704763188804809, 0.0005605046036985397, 0.0005791208421003413, 0.0005335326139117707, 0.0004934949519878694, 0.0004763342242951187, 0.0005172079217577617, 0.0005779743869391897, 0.0006042841008143257, 0.0005770573428119739, 0.0005450900048248701, 0.0005067311674379952, 0.0004968925287361806, 0.0004711118296206172, 0.0014171698341778065, 0.005690935779835017, 0.008510960307380279, 0.00935023299185716, 0.00929679200883621, 0.008987915971315203, 0.008761810898376198, 0.008603130108058316, 0.008559720759664399, 0.008783833007694896, 0.00901592918319725, 0.0092405652551742, 0.009523235206182158, 0.009805680762103043, 0.010064494227966013, 0.010285466666335856, 0.010564317150347469, 0.010904890199281665, 0.011300381973776254, 0.011752827666683818, 0.012251229169818028, 0.012601176322547406, 0.012282446790489012, 0.010792170002008234, 0.00647048513144431, 0.0018832684706656256, 0.0011394349566666857, 0.0011096812724578182, 0.0009870586509462002, 0.0008094464252433208, 0.0006661998543134056, 0.0006056960884608167, 0.0005395793416334771, 0.00046888738537370064, 0.000482058796523006, 0.0005431832509350191, 0.0006038661763912209, 0.0006624438902120272, 0.0007125657612998479, 0.000843891065804847, 0.0009337397936841058, 0.0009346086195590644, 0.0008763004077526087, 0.0007114108307844982, 0.0006020468776198993, 0.0005290694492725321, 0.0005003913756041098, 0.0005006385087037486, 0.0005778968355896624, 0.0007356363182117344, 0.0008655961271389149, 0.0010702531063782113, 0.0011908161424962042, 0.0012714170004793583, 0.0012978268407987665, 0.0012101711933792457, 0.0011414305148082194, 0.0011828987363528458, 0.0011701842724968709, 0.0011233622809625908, 0.0011187453462311646, 0.0011383502476823074, 0.0010879320969472972, 0.0010218571382007294, 0.0009590179516704866, 0.0009297814559376149, 0.0009417575762161462, 0.0010032587682198787, 0.0010834823130695856, 0.0011395261861756314, 0.0012183116770327054, 0.0013035929308549056, 0.0014058774885904865, 0.0013557437169614706, 0.0012360287831992738, 0.0011158601347494833, 0.0009418784064245236, 0.0008025001053500509, 0.0006680067693062688, 0.0006358591780881725, 0.0005729112778953616, 0.00059734 ...
#
# List of step sizes:
# [0.03633984183353146, 0.03780790320442082, 0.03541194310225045, 0.036821309650880076, 0.03749695997486012, 0.0347727216551279, 0.03336914923835054, 0.03189287936603198, 0.03335107889199271, 0.03606820161373898, 0.03525826609362128, 0.03273205616719314, 0.03426202989723282, 0.03435713389605443, 0.03421797776701491, 0.03447615242710181, 0.037551065533563084, 0.037426925701871575, 0.03771627722989387, 0.040421812878623044, 0.03901674593171377, 0.03882572890780436, 0.036124329821266336, 0.03469677500993533, 0.038221666884839835, 0.03870857797524494, 0.03953173546156945, 0.03941554821164177, 0.03768699937198829, 0.04022921595407438, 0.04180454629400979, 0.03901933148749743, 0.03969923961860362, 0.039255224451799096, 0.03985923902999635, 0.03653450855779329, 0.03773881411538976, 0.03623964295498433, 0.03316657600710958, 0.03280304759215701, 0.034042021600573194, 0.03422599926196452, 0.03616333147636505, 0.03236002256718828, 0.03196559098084262, 0.03213208769853746, 0.0305036693318591, 0.031198448239430975, 0.029515704225173665, 0.02962786656032961, 0.029174166011241686, 0.028125008746766957, 0.0288090227072516, 0.02801465954200441, 0.029537396780536154, 0.02809293961408154, 0.030964845702613836, 0.03101487181925973, 0.03277477610343688, 0.03294193931810729, 0.03166613069304224, 0.03064427602915119, 0.032520399079840986, 0.03134767850956197, 0.029240282825381467, 0.03360241133967963, 0.03169160813499854, 0.031180958190774925, 0.031455449967854314, 0.031085031193812136, 0.030312906334921966, 0.02989954645171553, 0.03160184740584287, 0.03060668435181042, 0.031235532610909705, 0.02923639386106603, 0.028802181807345388, 0.031085279639660048, 0.03329669491407652, 0.036450439221129, 0.03688364600831822, 0.03520002933335593, 0.03666642357588523, 0.038686768868253965, 0.03438033059051813, 0.035611534853135146, 0.036301867677590006, 0.03584254107753764, 0.03671921964156457, 0.03900300968718651, 0.03818873516834685, 0.039092260526609426, 0.03891034320450451, 0.039257234118842396, 0.038920051380638795, 0.039450088477883054, 0.03856477270016918, 0.03609603603978051, 0.052762331293697666, 0.08449531750695875, 0.09649653154791298, 0.09604857014255921, 0.09530379701720819, 0.09898001374494562, 0.10112726831715448, 0.09971601630031468, 0.101004524799384, 0.1061224384813814, 0.10471266517118105, 0.1063081654283276, 0.1047468964177517, 0.10444505861139035, 0.10740838893450429, 0.10816334400200014, 0.10837686769429154, 0.1063966631342669, 0.10490352988031519, 0.08853557080406882, 0.05703426476186398, 0.046861744705808804, 0.04591612851459495, 0.04629306084988052, 0.04255780261648199, 0.04155761561934549, 0.04206193939904352, 0.04198104883537518, 0.03674344780633714, 0.03533526428079886, 0.03461504088604318, 0.034827969184036356, 0.036373651962572306, 0.03238111921060105, 0.03275627865661738, 0.03373640172712656, 0.03316982460030818, 0.033120978563189844, 0.032072110405225396, 0.03393742356133961, 0.035382976189736605, 0.03800794713721663, 0.03984298670463699, 0.04080415215250811, 0.03974522563340094, 0.04026715710638268, 0.03978704460929272, 0.042179351020681884, 0.04614017466437786, 0.04924778061052439, 0.048765556338491466, 0.04906091289132414, 0.049918232508586256, 0.04860860515810527, 0.050603083144267265, 0.050928709673861136, 0.054834632478880804, 0.05600052144534439, 0.05171009321868719, 0.0482202794494716, 0.048468902475504505, 0.048958705771986355, 0.05003410428062829, 0.04943813329743774, 0.05176177420575592, 0.050655940300787176, 0.04808425590503709, 0.04496460238677289, 0.04161553384621353, 0.042105534423915715, 0.04121264099343206, 0.04139897308668811, 0.04218426682801416, 0.03763221584199667, 0.03674065175762702, 0.03813957677857877, 0.0352936167261386]

# %%
# Plot diffusion coefficient (D_app)
plt.figure(figsize=(7, 4))
plt.plot(arr_t_start, arr_log10D, lw=3, c="#9a3324")
plt.xlabel("Time (s)", fontsize=22)
plt.ylabel(r"D$_{app}$, $\mu$m$^2$/s", fontsize=22)
plt.ylim(0, None)
plt.gca().yaxis.set_label_coords(-0.26, 0.5)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(axis="both", which="major", labelsize=22, direction="in", bottom=True, left=True, length=5, width=1)
plt.xlim(arr_t_start[0], arr_t_start[-1])
plt.tight_layout()
plt.show()

# %%
# Plot alpha component (normal)
plt.figure(figsize=(7, 4))
plt.plot(arr_t_start, arr_alpha, lw=3, c="#9a3324")
plt.axhline(1.1, ls="--", c="gray", lw=2)
plt.xlabel("Time (s)", fontsize=22)
plt.ylabel(r"$\alpha$ component", fontsize=22)
plt.gca().yaxis.set_label_coords(-0.11, 0.5)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(axis="both", which="major", labelsize=22, direction="in", bottom=True, left=True, length=5, width=1)
plt.xlim(arr_t_start[0], arr_t_start[-1])
plt.tight_layout()
plt.show()

# %%
# Plot step size (mean step sizes)
plt.figure(figsize=(8, 4))

# Define the range for the red segment
red_start_index = 97
red_end_index = 138

# Debugging information
print(f"Total number of points: {len(arr_t_start)}")
print(f"Red segment start index: {red_start_index}, end index: {red_end_index}")

# Plot segments outside the red range in blue
if red_start_index > 0:
    plt.plot(arr_t_start[:red_start_index], arr_step_size[:red_start_index], lw=3, c="#00274c")
if red_end_index < len(arr_t_start):
    plt.plot(arr_t_start[red_end_index:], arr_step_size[red_end_index:], lw=3, c="#00274c")

# Plot the segment within the red range in red
if red_start_index < len(arr_t_start) and red_end_index <= len(arr_t_start):
    plt.plot(arr_t_start[red_start_index:red_end_index], arr_step_size[red_start_index:red_end_index], lw=3, c="#c61a3e")

# Customize plot
plt.xlabel("Time (s)", fontsize=22)
plt.ylabel(r"Mean Step Size, $\mu$m", fontsize=22)
plt.ylim(0, None)
plt.gca().yaxis.set_label_coords(-0.09, 0.5)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(axis="both", which="major", labelsize=fontsize, direction="in", bottom=True, left=True, length=5, width=1)
plt.xlim(arr_t_start[0], arr_t_start[-1])
plt.tight_layout()
plt.savefig("change_step_size_rep_track.png", format="png", bbox_inches="tight", dpi=600)
plt.show()
# Out:
# Total number of points: 175
# Red segment start index: 97, end index: 138

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as clr
import seaborn as sns
import matplotlib.cm as cm
from scipy import stats

# %%
file_path = r'Z:\Bisal_Halder_turbo\PROCESSED_DATA\Impact_of_cytoskeleton_on_HOPS_condensates\no_drug\Analysed Data\2x\Trackmate analysis new 07052024\flagged_tracks_w20\20240118_UGD-2x-2s-replicate1-FOV-2-wstepflags.csv' 
data = pd.read_csv(file_path)

# %%
data['step_flag'] = data['step_flag'].astype(str).str.upper() == 'TRUE'

# %%
def has_consecutive_true(df, col='step_flag'):
    return df[col].rolling(window=2).apply(lambda x: all(x), raw=True).any()

# %%
valid_track_ids = data.groupby('trackID').filter(has_consecutive_true)['trackID'].unique()
if len(valid_track_ids) == 0:
    raise ValueError("No trackIDs found with consecutive TRUE values in step_flag.")

# %%
track_id = 195  # Use a random track_id from valid_track_ids
# track_id = np.random.choice(valid_track_ids, 1)[0]
track_data = data[data['trackID'] == track_id].copy()

# %%
um_per_pixel = 0.117
track_data['x'] = track_data['x'] * um_per_pixel
track_data['y'] = track_data['y'] * um_per_pixel
s_per_frame = 2
track_data['t'] = track_data['t'] * s_per_frame

# %%
# Store results for future access
stored_track_data = track_data.copy()
stored_random_track_id = track_id
x = track_data['x'].values
y = track_data['y'].values
t = track_data['t'].values

# Debugging: Print x, y, t values
print("Debug information:")
print("Stored Track Data:")
print(stored_track_data)
# Out:
# Debug information:
# Stored Track Data:
#        trackID          x          y      t  R2  alpha   D  step_sizes  \
# 32151      195  35.795500  57.641286    0.0 NaN    NaN NaN         NaN
# 32152      195  35.810790  57.643472    2.0 NaN    NaN NaN    0.132018
# 32153      195  35.748289  57.626420    4.0 NaN    NaN NaN    0.553720
# 32154      195  35.779825  57.588105    6.0 NaN    NaN NaN    0.424137
# 32155      195  35.765743  57.622542    8.0 NaN    NaN NaN    0.317994
# ...        ...        ...        ...    ...  ..    ...  ..         ...
# 32346      195  35.066147  58.980443  390.0 NaN    NaN NaN    0.235306
# 32347      195  35.043979  59.036088  392.0 NaN    NaN NaN    0.511944
# 32348      195  35.133603  58.987121  394.0 NaN    NaN NaN    0.872894
# 32349      195  35.192316  58.998522  396.0 NaN    NaN NaN    0.511196
# 32350      195  35.118890  58.968847  398.0 NaN    NaN NaN    0.676886
#
#        mean_step_sizes      x_mean      y_mean cellID  step_flag
# 32151         0.382718  302.620756  497.507184  cell2      False
# 32152         0.382718  302.620756  497.507184  cell2      False
# 32153         0.382718  302.620756  497.507184  cell2      False
# 32154         0.382718  302.620756  497.507184  cell2      False
# 32155         0.382718  302.620756  497.507184  cell2      False
# ...                ...         ...         ...    ...        ...
# 32346         0.382718  302.620756  497.507184  cell2      False
# 32347         0.382718  302.620756  497.507184  cell2      False
# 32348         0.382718  302.620756  497.507184  cell2      False
# 32349         0.382718  302.620756  497.507184  cell2      False
# 32350         0.382718  302.620756  497.507184  cell2      False
#
# [200 rows x 13 columns]

# %%
# Function to calculate angles
def calc_angle(x, y):
    x0 = x[:-1]
    x1 = x[1:]
    y0 = y[:-1]
    y1 = y[1:]
    vector = np.array([x1 - x0, y1 - y0])
    vector_complex = 1j * vector[1, :] + vector[0, :]
    angles_eachstep = np.angle(vector_complex, deg=True)
    angles = np.ediff1d(angles_eachstep)
    angles[angles < -180] += 360
    angles[angles > 180] -= 360
    return angles

# %%
angles = calc_angle(x, y)

# %%
# Define the custom colormap from red to blue
color_red = "#c61a3e"
color_blue = "#00274c"
cmap_name = "red2blue"
cmap = clr.LinearSegmentedColormap.from_list(cmap_name, [color_red, color_blue], N=len(angles))
fontsize = 18
x_plot = x - (x.min() + x.max()) / 2
y_plot = y - (y.min() + y.max()) / 2

print(f"x_plot: {x_plot}")
print(f"y_plot: {y_plot}")

fig, ax = plt.subplots(figsize=(6, 4))

# Normalize the angles to the range [0, 1]
normalize_angles = clr.Normalize(vmin=0, vmax=180)
color_mapped_angles = cm.ScalarMappable(norm=normalize_angles, cmap=cmap).to_rgba(np.abs(angles))

# Plot the trajectory with color mapping based on angles
for i in range(len(angles)):
    ax.plot(
        x_plot[i:i + 2], y_plot[i:i + 2], "-o",
        color=color_mapped_angles[i],
        linewidth=2
    )

# Customize plot aesthetics
ax.axis("scaled")
ax.spines[:].set_linewidth(1)
ax.tick_params(
    axis="both",
    which="major",
    labelsize=fontsize,
    direction="in",
    bottom=True,
    left=True,
    length=5,
    width=1
)
ax.set_xlabel('X, um', fontsize=18)
ax.set_ylabel('Y, um', fontsize=18)

ax.relim()
ax.autoscale_view()

normalize = clr.Normalize(vmin=0, vmax=180)
cbar = plt.colorbar(
    cm.ScalarMappable(norm=normalize, cmap=cmap),
    ax=ax,
    orientation='horizontal',
    pad=0.2,
    drawedges=False
)
cbar.ax.tick_params(labelsize=fontsize)
cbar.set_label('Angle (degrees)', fontsize=18)

# Final layout adjustments and show the plot
plt.tight_layout()
plt.show()
# Out:
# x_plot: [ 0.4616084   0.47689894  0.41439821  0.44593362  0.43185214  0.41558164
#   0.3590464   0.3236465   0.32054197  0.32933356  0.29986493  0.32467625
#   0.27481642  0.30631151  0.28951638  0.29152977  0.31480902  0.30925238
#   0.28265673  0.30382969  0.34489401  0.32580336  0.30919077  0.34670388
#   0.33898852  0.31522696  0.34362661  0.32106883  0.29099388  0.30014734
#   0.30095705  0.30530015  0.29224565  0.26886478  0.26001974  0.17839287
#   0.20002998  0.17181511  0.13045355  0.13944681  0.15463701  0.17591318
#   0.19732491  0.11746769  0.15062427  0.14333176  0.17624218  0.18589371
#   0.24727969  0.21632976  0.2456313   0.26075516  0.27335231  0.29798514
#   0.31079587  0.27780463  0.27367373  0.25297684  0.25992257  0.23036423
#   0.23419359  0.23787011  0.24517433  0.26882592  0.2403292   0.2349906
#   0.27532406  0.29641649  0.25658491  0.24605144  0.27226769  0.2979295
#   0.30893119  0.26639484  0.2831583   0.26803616  0.2865633   0.26921287
#   0.29443662  0.29633761  0.29113795  0.29032722  0.2940307   0.294785
#   0.29245954  0.29197231  0.31148435  0.27767052  0.28861277  0.30184842
#   0.29401352  0.33516534  0.31411758  0.28581707  0.26545868  0.24706234
#   0.30363327  0.2197179   0.23784847  0.2500149   0.23969921  0.23063294
#   0.27696008  0.26958921  0.24106608  0.22641423  0.19912806  0.22515762
#   0.25161838  0.24903251  0.28501929  0.29152893  0.27250511  0.2848476
#   0.29252642  0.27670943  0.24286816 -0.04047592 -0.26793646 -0.45035193
#  -0.47689894 -0.44609012 -0.36856647 -0.32738115 -0.3251193  -0.35787604
#  -0.26560473 -0.29401615 -0.31541098 -0.32565882 -0.3450456  -0.35021188
#  -0.37921555 -0.3638883  -0.34929509 -0.34811543 -0.36340142 -0.3199728
#  -0.28613177 -0.27287504 -0.23356137 -0.22895207 -0.19861782 -0.21539822
#  -0.20365294 -0.19076011 -0.18748551 -0.1911879  -0.22611374 -0.27363467
#  -0.26836076 -0.26781241 -0.3172021  -0.32709147 -0.3348961  -0.31323184
#  -0.24678086 -0.24591152 -0.24988262 -0.22401345 -0.24537296 -0.2176698
#  -0.24417207 -0.28016814 -0.2391746  -0.17094793 -0.13562357 -0.16111681
#  -0.13833001 -0.11304599 -0.12443622 -0.12198756 -0.13204209 -0.06074836
#  -0.06412384 -0.05836209 -0.05113515  0.0162772  -0.05016513 -0.00834991
#  -0.02538455 -0.09222777 -0.07670318 -0.0987408  -0.1157641  -0.09902549
#  -0.06761902 -0.07633303 -0.09567975 -0.06920128 -0.06717895 -0.05923578
#  -0.14687489 -0.15144269 -0.24193581 -0.26774395 -0.28991228 -0.20028817
#  -0.14157504 -0.21500104]
# y_plot: [-0.66214958 -0.65996287 -0.67701523 -0.7153305  -0.68089295 -0.61825442
#  -0.63619721 -0.6812471  -0.69290083 -0.68568228 -0.68234571 -0.73265242
#  -0.71251559 -0.70053212 -0.68053868 -0.69134428 -0.69246857 -0.66902803
#  -0.65967264 -0.63472346 -0.62086653 -0.61830325 -0.54372924 -0.57685072
#  -0.56644168 -0.54405481 -0.53707309 -0.56982179 -0.62518052 -0.63612558
#  -0.62807169 -0.5453435  -0.57836125 -0.58037702 -0.56716805 -0.57126704
#  -0.57329015 -0.59170185 -0.51844427 -0.50444031 -0.50813319 -0.52140345
#  -0.51322892 -0.50982798 -0.53544154 -0.57973041 -0.56163243 -0.59020464
#  -0.60232072 -0.62441281 -0.63047976 -0.58447909 -0.59267983 -0.60461777
#  -0.61804734 -0.58801528 -0.59118445 -0.57588245 -0.5827049  -0.55699809
#  -0.52868492 -0.58830007 -0.59062969 -0.5656457  -0.60433177 -0.60824371
#  -0.62415671 -0.60199017 -0.607091   -0.58857474 -0.59972532 -0.58845513
#  -0.59391112 -0.5727892  -0.56908143 -0.51125321 -0.53046495 -0.56999936
#  -0.5359814  -0.53209035 -0.57206678 -0.61537226 -0.62691442 -0.61894186
#  -0.52947319 -0.53651018 -0.54398775 -0.57424103 -0.56508949 -0.56111781
#  -0.57970798 -0.59696569 -0.61630537 -0.6094596  -0.61722501 -0.61849007
#  -0.55298318 -0.54427357 -0.60591421 -0.65290898 -0.65758096 -0.61863917
#  -0.62114235 -0.61899764 -0.60834712 -0.57765271 -0.6021133  -0.58542165
#  -0.53469795 -0.53862567 -0.48839544 -0.46412597 -0.43390791 -0.42472702
#  -0.39727008 -0.32935561 -0.34541895 -0.09084167  0.51963024  0.67458761
#   0.69149153  0.70100439  0.70060557  0.64247162  0.64930535  0.59769659
#   0.50874994  0.4978654   0.52558641  0.49513781  0.49467039  0.58653616
#   0.59305298  0.56431775  0.53571759  0.54473134  0.61296009  0.643246
#   0.67450599  0.67192686  0.67461902  0.67927943  0.72181124  0.72176491
#   0.66334415  0.68892657  0.68727052  0.66626147  0.65684681  0.64592269
#   0.63065511  0.66750585  0.65405032  0.63513656  0.63752712  0.59247356
#   0.65075326  0.57722336  0.51396816  0.44434746  0.45698277  0.47324067
#   0.47646065  0.44108748  0.50281713  0.54249466  0.61469369  0.60576914
#   0.65513607  0.67546324  0.6717769   0.5827257   0.60835401  0.56708833
#   0.49502382  0.49128441  0.49143811  0.50111645  0.55181811  0.56910981
#   0.58104194  0.60451935  0.62955307  0.61724976  0.62706808  0.62753078
#   0.60928812  0.57291006  0.60324852  0.60794917  0.60957669  0.61658107
#   0.68131515  0.66383173  0.6865939   0.67700835  0.73265242  0.68368541
#   0.69508681  0.66541226]

# %% [markdown]
# ## Angle distribution with time for the representative track

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r'Z:\Bisal_Halder_turbo\PROCESSED_DATA\Impact_of_cytoskeleton_on_HOPS_condensates\no_drug\Analysed Data\2x\Trackmate analysis new 07052024\flagged_tracks_w20\20240118_UGD-2x-2s-replicate1-FOV-2-wstepflags.csv'
data = pd.read_csv(file_path)

# %%
data['step_flag'] = data['step_flag'].astype(str).str.upper() == 'TRUE'
def has_consecutive_true(df, col='step_flag'):
    return df[col].rolling(window=2).apply(lambda x: all(x), raw=True).any()

valid_track_ids = data.groupby('trackID').filter(has_consecutive_true)['trackID'].unique()
if len(valid_track_ids) == 0:
    raise ValueError("No trackIDs found with consecutive TRUE values in step_flag.")

track_id = 195  # Use a random track_id from valid_track_ids
# track_id = np.random.choice(valid_track_ids, 1)[0]
track_data = data[data['trackID'] == track_id].copy()

# %%
um_per_pixel = 0.117
track_data['x'] = track_data['x'] * um_per_pixel
track_data['y'] = track_data['y'] * um_per_pixel
s_per_frame = 2
track_data['t'] = track_data['t'] * s_per_frame

# %%
x = track_data['x'].values
y = track_data['y'].values
t = track_data['t'].values[1:]

# Debugging: Print x, y, t values
# print("Debug information:")
# print("Stored Track Data:")
# print(stored_track_data)

# %%
def calc_angle(x, y):
    x0 = x[:-1]
    x1 = x[1:]
    y0 = y[:-1]
    y1 = y[1:]
    vector = np.array([x1 - x0, y1 - y0])
    vector_complex = 1j * vector[1, :] + vector[0, :]
    angles_eachstep = np.angle(vector_complex, deg=True)
    angles = np.ediff1d(angles_eachstep)
    angles[angles < -180] += 360
    angles[angles > 180] -= 360
    return angles

angles = calc_angle(x, y)

# %%
t = t[:len(angles)]
angles_time_data = pd.DataFrame({'time': t, 'angle_change': angles})

# Plot the angle distribution
plt.figure(figsize=(4, 3))
bins = 16
sns.lineplot(
    data=angles_time_data,
    x="time",
    y="angle_change",
    lw=2,
    marker='o',
    color="#c46666"
)
# plt.axhline(1 / bins, ls="--", c="gray", lw=2)
# plt.text(
#     10,
#     0.05,
#     r"N$_{step}$=" + f"{angles_data.shape[0]:,}",
#     fontdict={"fontsize":18},
# )
plt.xlim(angles_time_data['time'].min(), angles_time_data['time'].max())
plt.ylim(angles_time_data['angle_change'].min() - 10, angles_time_data['angle_change'].max() + 10)
plt.xlabel("Time (s)", fontsize=18)
plt.ylabel("Angle Change ($^\circ$)", fontsize=18)
plt.gca().spines[:].set_linewidth(1)
plt.gca().tick_params(
    axis="both",
    which="major",
    labelsize=18,
    direction="in",
    bottom=True,
    left=True,
    length=5,
    width=1,
)
# plt.axhline(0, ls="--", c="gray", lw=2) # Add a horizontal line at y=0 for reference
plt.tight_layout()
plt.savefig("angle_vs_time.png", format="png", bbox_inches="tight", dpi=300)
plt.show()
